# %% [markdown]
# # Reproduction
#
# This notebook currently imports results from a run of PHC.py and attempts to map them to Table 6.
#
# Table 6 results are from Shoaib M, Ramamohan V. **Simulation modeling and analysis of primary health center operations**. *SIMULATION* 98(3):183-208. (2022). <https://doi.org/10.1177/00375497211030931>.

# %% [markdown]
# ## Set up

# %%
import xlrd
import pandas as pd

# %%
results_path = 'outputs/outputs.xls'
full_results_path = 'outputs/full_results.xlsx'
table6_path = '../original_study/tab6.csv'

# %% [markdown]
# ## Import results

# %%
# Import .xls and convert to pandas dataframe
book = xlrd.open_workbook(results_path)
result = pd.read_excel(book, header=None, index_col=0)
result
# Out:
#                             1             2              3              4   \
# 0
# OPD patients      32836.000000  33066.000000   33023.000000   32870.000000
# IPD patients        174.000000    166.000000     171.000000     177.000000
# ANC patients        368.000000    362.000000     386.000000     380.000000
# Del patients        384.000000    367.000000     369.000000     361.000000
# OPD Q wt              0.006038      0.008066       0.006059       0.006793
# Pharmacy Q wt         1.047611      1.019909       1.011980       1.016690
# Lab Q wt              2.063080      2.096727       2.121108       1.958464
# doc occ               0.269761      0.271455       0.265695       0.271491
# Lab patient list  34553.000000  68973.000000  103851.000000  137618.000000
# OPD q len             0.005855      0.009359       0.004993       0.007724
# ipd occ               0.100000      0.100000       0.100000       0.100000
# opd q len             0.000531      0.000713       0.000535       0.000598
# pharmacy q len        0.091809      0.089833       0.089091       0.089266
# lab q len             0.093966      0.095058       0.097672       0.087332
# NCD occ               0.856243      0.876655       0.868920       0.862815
# lab occ               0.559366      0.552778       0.566939       0.550767
# pharm occ             0.637989      0.643297       0.639525       0.638504
# staff nurse occ       0.328762      0.322683       0.321956       0.321020
# del occ               0.280000      0.290000       0.300000       0.290000
# del referred         58.000000     53.000000      56.000000      54.000000
# NCD occ               0.856243      0.876655       0.868920       0.862815
# ipd bed occ           0.101028      0.091502       0.097690       0.092269
#
#                              5              6              7              8   \
# 0
# OPD patients       33240.000000   33232.000000   33216.000000   33368.000000
# IPD patients         198.000000     194.000000     206.000000     178.000000
# ANC patients         388.000000     381.000000     372.000000     370.000000
# Del patients         309.000000     360.000000     359.000000     397.000000
# OPD Q wt               0.005244       0.010225       0.007012       0.016915
# Pharmacy Q wt          1.006467       1.032219       1.020334       1.017687
# Lab Q wt               2.096112       2.160190       2.039157       2.069498
# doc occ                0.266211       0.269985       0.269385       0.274394
# Lab patient list  172163.000000  206714.000000  241073.000000  275273.000000
# OPD q len              0.005061       0.011423       0.005998       0.010305
# ipd occ                0.090000       0.100000       0.090000       0.100000
# opd q len              0.000462       0.000909       0.000619       0.001494
# pharmacy q len         0.088519       0.091496       0.089756       0.089564
# lab q len              0.095604       0.098494       0.092430       0.093381
# NCD occ                0.875444       0.864627       0.873573       0.882904
# lab occ                0.558711       0.559475       0.554049       0.557318
# pharm occ              0.644518       0.642726       0.645787       0.647810
# staff nurse occ        0.305951       0.322970       0.323056       0.335735
# del occ                0.260000       0.290000       0.280000       0.300000
# del referred          44.000000      55.000000      55.000000      62.000000
# NCD occ                0.875444       0.864627       0.873573       0.882904
# ipd bed occ            0.082897       0.094390       0.091500       0.098772
#
#                              9              10
# 0
# OPD patients       33314.000000   33171.000000
# IPD patients         198.000000     178.000000
# ANC patients         350.000000     355.000000
# Del patients         385.000000     339.000000
# OPD Q wt               0.008484       0.018205
# Pharmacy Q wt          1.017410       1.003815
# Lab Q wt               2.135470       2.139755
# doc occ                0.270916       0.264823
# Lab patient list  309924.000000  344492.000000
# OPD q len              0.010064       0.017429
# ipd occ                0.100000       0.100000
# opd q len              0.000751       0.001609
# pharmacy q len         0.089736       0.088452
# lab q len              0.097421       0.097366
# NCD occ                0.885179       0.851488
# lab occ                0.562513       0.553164
# pharm occ              0.647879       0.641500
# staff nurse occ        0.331135       0.312820
# del occ                0.300000       0.280000
# del referred          72.000000      47.000000
# NCD occ                0.885179       0.851488
# ipd bed occ            0.092360       0.090019

# %%
# Import .xlsx and convert to pandas dataframe and rename for clarity
full_result = pd.read_excel(full_results_path, header=None).rename(columns={
    0: 'full_outcome',
    1: 'full_result'})
full_result
# Out:
#                            full_outcome    full_result
# 0        OPD patient inter-arrival time       4.000000
# 1        IPD patient inter-arrival time    2880.000000
# 2   Delivery patient inter-arrival time    1440.000000
# 3        ANC patient inter-arrival time    1440.000000
# 4         Doctor consultation time mean       0.870000
# 5           Doctor consultation time SD       0.210000
# 6                      Number of doctor       2.000000
# 7                Number of staff nurses       3.000000
# 8              Number of lab technician       1.000000
# 9                  Number of pharmacist       1.000000
# 10                    Total OPD minutes  261120.000000
# 11                 OPD patients per day     127.000000
# 12               OPD patients per month    2210.000000
# 13                      Doctor OPD time   40439.790000
# 14                      Doctor IPD time     216.200000
# 15                 Doctor Delivery time    5615.730000
# 16                    Doctor admin time    3586.600000
# 17                    Doctor total time       0.000000
# 18                   NCD Nurse OPD time       0.000000
# 19                 NCD Nurse Admin time    3586.600000
# 20                 Staff Nurse IPD time    8261.689000
# 21            Staff Nurse Delivery time   65417.096000
# 22                 Staff Nurse ANC time    8989.003000
# 23               Staff Nurse Admin time     154.230000
# 24                Staff Nurse total ime       0.000000
# 25                      Pharmacist Time       0.000000
# 26                             Lab Time   85466.000000
# 27      Average time spent with doctors       1.000000
# 28        Average time of bed occupancy     629.000000
# 29                     Doctor Occupancy       0.269412
# 30                  NCD Nurse Occupancy       0.870000
# 31                Staff nurse Occupancy       0.320000
# 32                 Pharmacist Occupancy       0.642954
# 33                        Lab Occupancy       0.560000
# 34                        Bed occupancy       0.100000
# 35             Mean length of OPD queue       0.000800
# 36               OPD queue waiting time       0.009300
# 37        Mean length of pharmacy queue       0.090000
# 38          Pharmacy queue waiting time       1.020000
# 39             Mean length of Lab queue       0.090000
# 40               Lab queue waiting time       2.090000
# 41                                 OPDs   46363.000000
# 42                                 IPDs     184.100000
# 43                           Deliveries     363.000000
# 44                                 ANCs     371.200000
# 45                     Total ANC visits     982.300000
# 46                 Delivery in OPD time     124.000000
# 47              Delivery after OPD time     183.500000
# 48                         Replications      10.000000
# 49               OPD queue wait time SD       0.004588
# 50              OPD queue max wait time       0.018205
# 51          Pharmacy queue wait time SD       0.012652
# 52         Pharmacy queue max wait time       1.047611
# 53               lab queue wait time SD       0.059170
# 54              Lab queue max wait time       2.160190
# 55                         Lab Patients  189463.400000
# 56                     Lab patients std   98843.788541

# %%
# Import table 6
t6 = pd.read_csv(table6_path)
t6_c1 = t6[['outcome', 'config1_mean']].rename(columns={
    'outcome': 't6_outcome',
    'config1_mean': 't6_result'
})
t6_c1
# Out:
#                                            t6_outcome  t6_result
# 0                                  Doctor utilisation      0.268
# 1                               NCD Nurse utilisation      0.865
# 2                             Staff nurse utilisation      0.323
# 3                              Pharmacist utilisation      0.643
# 4                                     Lab utilisation      0.559
# 5                           Inpatient bed utilisation      0.093
# 6                              Labour bed utilisation      0.283
# 7       Mean length of OPD queue (number of patients)      0.000
# 8                    OPD queue waiting time (minutes)      0.009
# 9   Mean length of pharmacy queue (number of patie...      0.090
# 10              Pharmacy queue waiting time (minutes)      1.025
# 11      Mean length of Lab queue (number of patients)      0.094
# 12                   Lab queue waiting time (minutes)      2.084
# 13              Fraction of childbirth cases referred      0.156

# %% [markdown]
# ## Add table 6 labels to full results

# %%
# Create dictionary to map between this and table 6
t6_labels = {
  'Doctor Occupancy': 'Doctor utilisation',
  'NCD Nurse Occupancy': 'NCD Nurse utilisation',
  'Staff nurse Occupancy': 'Staff nurse utilisation',
  'Pharmacist Occupancy': 'Pharmacist utilisation',
  'Lab Occupancy': 'Lab utilisation',
  'Bed occupancy': 'Inpatient bed utilisation',
  # '': 'Labour bed utilisation',  # Can't spot result in this table
  'Mean length of OPD queue': 'Mean length of OPD queue (number of patients)',
  'OPD queue waiting time': 'OPD queue waiting time (minutes)',
  'Mean length of pharmacy queue': 'Mean length of pharmacy queue (number of patients)',
  'Pharmacy queue waiting time': 'Pharmacy queue waiting time (minutes)',
  'Mean length of Lab queue': 'Mean length of Lab queue (number of patients)',
  'Lab queue waiting time': 'Lab queue waiting time (minutes)',
  # '': 'Fraction of childbirth cases referred'  # Can't spot result in this table
}

# %% [markdown]
# Compared for all except 2 which weren't in table (labour bed utilisation and fraction of childbirth cases referred).

# %%
# Add labels to model results
full_result['t6_outcome'] = full_result['full_outcome'].map(t6_labels)

# %% [markdown]
# ## Processing replication outputs and add table 6 labels

# %%
# Find mean from the replications
av_result = result.mean(axis=1)

# Calculate the proportion of childbirth cases referred and add to series
prop_del_referred = pd.Series(
    av_result['del referred'] / av_result['Del patients'],
    index=['prop_del_referred'])
new_av_result = pd.concat([av_result, prop_del_referred])

# Convert to df, save as model config1, drop duplicates, and display
simple_result = (new_av_result
                 .to_frame(name='simple_result')
                 .reset_index()
                 .rename(columns= {'index': 'simple_outcome'})
                 .drop_duplicates())
simple_result
# Out:
#        simple_outcome  simple_result
# 0        OPD patients   33133.600000
# 1        IPD patients     184.000000
# 2        ANC patients     371.200000
# 3        Del patients     363.000000
# 4            OPD Q wt       0.009304
# 5       Pharmacy Q wt       1.019412
# 6            Lab Q wt       2.087956
# 7             doc occ       0.269412
# 8    Lab patient list  189463.400000
# 9           OPD q len       0.008821
# 10            ipd occ       0.098000
# 11          opd q len       0.000822
# 12     pharmacy q len       0.089752
# 13          lab q len       0.094872
# 14            NCD occ       0.869785
# 15            lab occ       0.557508
# 16          pharm occ       0.642954
# 17    staff nurse occ       0.322609
# 18            del occ       0.287000
# 19       del referred      55.600000
# 21        ipd bed occ       0.093243
# 22  prop_del_referred       0.153168

# %%
# Make dictionary with labels from table 6, and corresponding names from model output
t6_labels = {
  'doc occ': 'Doctor utilisation',
  'NCD occ': 'NCD Nurse utilisation',
  'staff nurse occ': 'Staff nurse utilisation',
  'pharm occ': 'Pharmacist utilisation',
  'lab occ': 'Lab utilisation',
  'ipd bed occ': 'Inpatient bed utilisation',
  'del occ': 'Labour bed utilisation',  # "Del" stands for delivery
  'OPD q len': 'Mean length of OPD queue (number of patients)',
  'OPD Q wt': 'OPD queue waiting time (minutes)',
  'pharmacy q len': 'Mean length of pharmacy queue (number of patients)',
  'Pharmacy Q wt': 'Pharmacy queue waiting time (minutes)',
  'lab q len': 'Mean length of Lab queue (number of patients)',
  'Lab Q wt': 'Lab queue waiting time (minutes)',
  'prop_del_referred': 'Fraction of childbirth cases referred'
}

# %%
# Add labels to model results
simple_result['t6_outcome'] = simple_result['simple_outcome'].map(t6_labels)

# %% [markdown]
# ## Combine all three
#
# simple_result and full_result
#
# Match:
#
# * doctor utilisation
# * pharmacist utilisation
#
# Don't match:
#
# * ncd nurse utilisation (rounding?)
# * staff nurse utilisation (rounding?)
# * lab utilisation (rounding?)
# * bed occupancy (rounding?)
# * mean OPD queue length (rounding as simple results using replication spreadsheet which might have rounding)
# * OPD queue waiting times (rounding?)
# * mean pharmacy queue length (rounding?)
# * pharacy queue waiting tim (rounding?)
# * lab queue waiting time (rounding?)

# %%
# Merge and set column order
compare = t6_c1.merge(simple_result).merge(full_result, how='left')[
    ['t6_outcome', 'simple_outcome', 'full_outcome',
     't6_result', 'simple_result', 'full_result']]

compare
# Out:
#                                            t6_outcome     simple_outcome  \
# 0                                  Doctor utilisation            doc occ
# 1                               NCD Nurse utilisation            NCD occ
# 2                             Staff nurse utilisation    staff nurse occ
# 3                              Pharmacist utilisation          pharm occ
# 4                                     Lab utilisation            lab occ
# 5                           Inpatient bed utilisation        ipd bed occ
# 6                              Labour bed utilisation            del occ
# 7       Mean length of OPD queue (number of patients)          OPD q len
# 8                    OPD queue waiting time (minutes)           OPD Q wt
# 9   Mean length of pharmacy queue (number of patie...     pharmacy q len
# 10              Pharmacy queue waiting time (minutes)      Pharmacy Q wt
# 11      Mean length of Lab queue (number of patients)          lab q len
# 12                   Lab queue waiting time (minutes)           Lab Q wt
# 13              Fraction of childbirth cases referred  prop_del_referred
#
#                      full_outcome  t6_result  simple_result  full_result
# 0                Doctor Occupancy      0.268       0.269412     0.269412
# 1             NCD Nurse Occupancy      0.865       0.869785     0.870000
# 2           Staff nurse Occupancy      0.323       0.322609     0.320000
# 3            Pharmacist Occupancy      0.643       0.642954     0.642954
# 4                   Lab Occupancy      0.559       0.557508     0.560000
# 5                   Bed occupancy      0.093       0.093243     0.100000
# 6                             NaN      0.283       0.287000          NaN
# 7        Mean length of OPD queue      0.000       0.008821     0.000800
# 8          OPD queue waiting time      0.009       0.009304     0.009300
# 9   Mean length of pharmacy queue      0.090       0.089752     0.090000
# 10    Pharmacy queue waiting time      1.025       1.019412     1.020000
# 11       Mean length of Lab queue      0.094       0.094872     0.090000
# 12         Lab queue waiting time      2.084       2.087956     2.090000
# 13                            NaN      0.156       0.153168          NaN
