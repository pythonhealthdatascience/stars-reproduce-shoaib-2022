# %% [markdown]
# # Reproducing Table 6
#
# This notebook currently imports results from a run of PHC.py and maps them to Table 6.
#
# Table 6 results are from Shoaib M, Ramamohan V. **Simulation modeling and analysis of primary health center operations**. *SIMULATION* 98(3):183-208. (2022). <https://doi.org/10.1177/00375497211030931>.
#
# Run time: **61 minutes**. Will need to uncomment the timer sections and section to run model if you wish to fully rerun. These are currently commented so the notebook can otherwise be used for processing the results.

# %% [markdown]
# ## Set up

# %%
# To run model
import PHC
import numpy as np

# To import and process results
from reproduction_helpers import process_results
import pandas as pd
import xlrd
import os

# To speed up run time
from multiprocessing import Pool

'''# Additional package to record runtime of this notebook
import time
start = time.time()'''
# Out:
# '# Additional package to record runtime of this notebook\nimport time\nstart = time.time()'

# %%
table6_path = '../original_study/tab6.csv'
final_results = 'outputs/tab6.csv'

# %% [markdown]
# ## Run model
#
# Set parameters for each configuration based on Table 3.

# %%
# For all: days 365, warm up 180, 6 inpatient beds, 1 delivery
# bed, 3 staff nurse, 1 NCD nurse. These are default parameters in the model,
# and below, have just specified the parameters that changed between
# configurations

t6_c1_param = {
    'doc_cap': 2,
    'OPD_iat': 4,
    'IPD_iat': 2880,
    'delivery_iat': 1440,
    'ANC_iat': 1440,
    'rep_file': 't6_c1.xls',
    'replication': 100
}

t6_c2_param = {
    'doc_cap': 1,
    'OPD_iat': 9,
    'IPD_iat': 2880,
    'delivery_iat': 2880,
    'ANC_iat': 2880,
    'rep_file': 't6_c2.xls',
    'replication': 100
}

t6_c3_param = {
    'doc_cap': 1,
    'OPD_iat': 9,
    'IPD_iat': 2880,
    'any_delivery': False,
    'any_ANC': False,
    'rep_file': 't6_c3.xls',
    'replication': 100
}

t6_c4_param = {
    'doc_cap': 2,
    'OPD_iat': 3,
    'mean': 5,
    'sd': 1,
    'consult_boundary_1': 2,
    'consult_boundary_2': 2,
    'IPD_iat': 2880,
    'delivery_iat': 1440,
    'ANC_iat': 1440,
    'rep_file': 't6_c4.xls',
    'replication': 100
}

# %%
# Create list of parameter dictionaries
config = [t6_c1_param, t6_c2_param, t6_c3_param, t6_c4_param]

# Append 's_' to all items
for i, d in enumerate(config):
    config[i] = {f's_{k}': v for k, v in d.items()}

# %% [markdown]
# Run model for each configuration using parallel processing.
#
# **Note:** Commented out due to long run time.

# %%
'''# Wrapper function to allow input of dictionary with pool
def wrapper(d):
    return PHC.main(**d)

# Create a process pool that uses all CPUs
with Pool(4) as pool:
    # Run PHC.main() using each of inputs from config
    pool.map(wrapper, config)'''
# Out:
# '# Wrapper function to allow input of dictionary with pool\ndef wrapper(d):\n    return PHC.main(**d)\n\n# Create a process pool that uses all CPUs\nwith Pool(4) as pool:\n    # Run PHC.main() using each of inputs from config\n    pool.map(wrapper, config)'

# %% [markdown]
# ## Import and process replication results

# %%
# Make dictionary with labels from table 6, and corresponding names from model output
t6_labels = {
  'doc occ': 'Doctor utilisation',
  'NCD occ': 'NCD Nurse utilisation',
  'staff nurse occ': 'Staff nurse utilisation',
  'pharm occ': 'Pharmacist utilisation',
  'lab occ': 'Lab utilisation',
  'ipd bed occ': 'Inpatient bed utilisation',
  'del occ': 'Labour bed utilisation',  # "Del" stands for delivery
  'opd q len': 'Mean length of OPD queue (number of patients)',
  'OPD Q wt': 'OPD queue waiting time (minutes)',
  'pharmacy q len': 'Mean length of pharmacy queue (number of patients)',
  'Pharmacy Q wt': 'Pharmacy queue waiting time (minutes)',
  'lab q len': 'Mean length of Lab queue (number of patients)',
  'Lab Q wt': 'Lab queue waiting time (minutes)',
  'prop_del_referred': 'Fraction of childbirth cases referred'
}

# %%
# Get results from those files
files = ['t6_c1', 't6_c2', 't6_c3', 't6_c4']
summary = process_results(files, sd=True).reset_index().rename(
    columns= {'index': 'model_outcome'})

# Add labels to model results
summary['t6_outcome'] = summary['model_outcome'].map(t6_labels)

summary
# Out:
#         model_outcome  model_t6_c1_mean  model_t6_c1_sd  model_t6_c2_mean  \
# 0        OPD patients      3.312637e+04    1.785897e+02      14890.180000
# 1        IPD patients      1.819400e+02    1.219026e+01        181.990000
# 2        ANC patients      3.643800e+02    1.464377e+01        211.900000
# 3        Del patients      3.654500e+02    1.906574e+01        181.470000
# 4            OPD Q wt      8.811218e-03    3.391605e-03          0.182605
# 5       Pharmacy Q wt      1.025055e+00    2.226311e-02          0.244612
# 6            Lab Q wt      2.076878e+00    5.626489e-02          0.604793
# 7             doc occ      2.686463e-01    2.152930e-03          0.372444
# 8    Lab patient list      1.747950e+06    1.003715e+06     780873.910000
# 9           OPD q len      8.397417e-03    4.244432e-03          0.177137
# 10            ipd occ      9.680000e-02    4.898979e-03          0.059200
# 11          opd q len      7.778837e-04    3.002725e-04          0.007237
# 12     pharmacy q len      9.021882e-02    2.221468e-03          0.009664
# 13          lab q len      9.470264e-02    2.732832e-03          0.012461
# 14            NCD occ      8.661105e-01    9.540874e-03          0.468966
# 15            lab occ      5.590886e-01    7.612054e-03          0.253639
# 16          pharm occ      6.429655e-01    3.610861e-03          0.288813
# 17    staff nurse occ      3.228974e-01    7.589217e-03          0.243063
# 18            del occ      2.826000e-01    1.177397e-02          0.152300
# 19       del referred      5.640000e+01    7.697566e+00         15.720000
# 20        ipd bed occ      9.370063e-02    4.367457e-03          0.055842
# 21  prop_del_referred      1.540155e-01    1.645332e-02          0.086324
#
#     model_t6_c2_sd  model_t6_c3_mean  model_t6_c3_sd  model_t6_c4_mean  \
# 0       110.461052      14857.250000      109.384816      4.405896e+04
# 1        13.949762        183.540000       14.546630      1.843800e+02
# 2        11.898986          0.000000        0.000000      3.676700e+02
# 3        14.669046               NaN             NaN      3.664800e+02
# 4         0.029487          0.034597        0.001101      6.968764e+00
# 5         0.008553          0.231061        0.006068      1.284367e+00
# 6         0.022624          0.569570        0.018696      3.152544e+00
# 7         0.003851          0.353664        0.002500      1.143672e+00
# 8    449025.249681     782899.560000   450041.784075      2.313950e+06
# 9         0.036704          0.034150        0.001157      6.842035e+00
# 10        0.003674          0.012500        0.004352      9.620000e-02
# 11        0.001175          0.001365        0.000047      8.172893e-01
# 12        0.000364          0.009116        0.000268      1.502997e-01
# 13        0.000534          0.011257        0.000411      1.889212e-01
# 14        0.005556          0.467952        0.004912      1.231325e+00
# 15        0.004737          0.239393        0.004237      7.337385e-01
# 16        0.002505          0.288200        0.002420      8.554212e-01
# 17        0.005772          0.160844        0.001431      3.239551e-01
# 18        0.010717               NaN             NaN      2.815000e-01
# 19        3.814062               NaN             NaN      5.901000e+01
# 20        0.003817          0.011606        0.000960      9.386653e-02
# 21        0.018355               NaN             NaN      1.605759e-01
#
#     model_t6_c4_sd                                         t6_outcome
# 0     2.118088e+02                                                NaN
# 1     1.455382e+01                                                NaN
# 2     1.572494e+01                                                NaN
# 3     2.039978e+01                                                NaN
# 4     2.516115e-01                   OPD queue waiting time (minutes)
# 5     1.971490e-02              Pharmacy queue waiting time (minutes)
# 6     7.267482e-02                   Lab queue waiting time (minutes)
# 7     5.670042e-03                                 Doctor utilisation
# 8     1.329765e+06                                                NaN
# 9     2.987361e-01                                                NaN
# 10    5.276209e-03                                                NaN
# 11    3.179206e-02      Mean length of OPD queue (number of patients)
# 12    2.681526e-03  Mean length of pharmacy queue (number of patie...
# 13    5.530848e-03      Mean length of Lab queue (number of patients)
# 14    1.873619e-02                              NCD Nurse utilisation
# 15    1.190204e-02                                    Lab utilisation
# 16    4.398680e-03                             Pharmacist utilisation
# 17    7.993417e-03                            Staff nurse utilisation
# 18    1.282162e-02                             Labour bed utilisation
# 19    8.879092e+00                                                NaN
# 20    4.481425e-03                          Inpatient bed utilisation
# 21    1.899443e-02              Fraction of childbirth cases referred

# %% [markdown]
# ## Import table 6 results and compare against run results

# %%
# Import table 6
t6 = pd.read_csv(table6_path).rename(columns={'outcome': 't6_outcome'})
t6
# Out:
#                                            t6_outcome  config1_mean  \
# 0                                  Doctor utilisation         0.268
# 1                               NCD Nurse utilisation         0.865
# 2                             Staff nurse utilisation         0.323
# 3                              Pharmacist utilisation         0.643
# 4                                     Lab utilisation         0.559
# 5                           Inpatient bed utilisation         0.093
# 6                              Labour bed utilisation         0.283
# 7       Mean length of OPD queue (number of patients)         0.000
# 8                    OPD queue waiting time (minutes)         0.009
# 9   Mean length of pharmacy queue (number of patie...         0.090
# 10              Pharmacy queue waiting time (minutes)         1.025
# 11      Mean length of Lab queue (number of patients)         0.094
# 12                   Lab queue waiting time (minutes)         2.084
# 13              Fraction of childbirth cases referred         0.156
#
#     config1_sd  config2_mean  config2_sd  config3_mean  config3_sd  \
# 0        0.003         0.372       0.004         0.354       0.002
# 1        0.011         0.469       0.005         0.468       0.005
# 2        0.008         0.243       0.006         0.160       0.001
# 3        0.004         0.288       0.003         0.289       0.003
# 4        0.008         0.254       0.004         0.239       0.004
# 5        0.004         0.055       0.003         0.011       0.001
# 6        0.010         0.153       0.009           NaN         NaN
# 7        0.000         0.007       0.001         0.001       0.000
# 8        0.004         0.171       0.032         0.034       0.001
# 9        0.002         0.010       0.001         0.009       0.000
# 10       0.021         0.244       0.008         0.232       0.006
# 11       0.003         0.012       0.001         0.011       0.000
# 12       0.054         0.606       0.023         0.571       0.020
# 13       0.019         0.088       0.022           NaN         NaN
#
#     benchmark_mean  benchmark_sd
# 0            1.142         0.006
# 1            1.232         0.019
# 2            0.322         0.008
# 3            0.855         0.005
# 4            0.736         0.011
# 5            0.093         0.004
# 6            0.281         0.012
# 7            0.817         0.027
# 8            6.789         0.268
# 9            0.150         0.002
# 10           1.282         0.018
# 11           0.188         0.001
# 12           3.135         0.005
# 13           0.157         0.180

# %%
# Round to 3dp (as in table) and merge
compare = t6.merge(round(summary,3))
compare.head()
# Out:
#                 t6_outcome  config1_mean  config1_sd  config2_mean  \
# 0       Doctor utilisation         0.268       0.003         0.372
# 1    NCD Nurse utilisation         0.865       0.011         0.469
# 2  Staff nurse utilisation         0.323       0.008         0.243
# 3   Pharmacist utilisation         0.643       0.004         0.288
# 4          Lab utilisation         0.559       0.008         0.254
#
#    config2_sd  config3_mean  config3_sd  benchmark_mean  benchmark_sd  \
# 0       0.004         0.354       0.002           1.142         0.006
# 1       0.005         0.468       0.005           1.232         0.019
# 2       0.006         0.160       0.001           0.322         0.008
# 3       0.003         0.289       0.003           0.855         0.005
# 4       0.004         0.239       0.004           0.736         0.011
#
#      model_outcome  model_t6_c1_mean  model_t6_c1_sd  model_t6_c2_mean  \
# 0          doc occ             0.269           0.002             0.372
# 1          NCD occ             0.866           0.010             0.469
# 2  staff nurse occ             0.323           0.008             0.243
# 3        pharm occ             0.643           0.004             0.289
# 4          lab occ             0.559           0.008             0.254
#
#    model_t6_c2_sd  model_t6_c3_mean  model_t6_c3_sd  model_t6_c4_mean  \
# 0           0.004             0.354           0.002             1.144
# 1           0.006             0.468           0.005             1.231
# 2           0.006             0.161           0.001             0.324
# 3           0.003             0.288           0.002             0.855
# 4           0.005             0.239           0.004             0.734
#
#    model_t6_c4_sd
# 0           0.006
# 1           0.019
# 2           0.008
# 3           0.004
# 4           0.012

# %%
compare_col = [
    ('config1_mean', 'model_t6_c1_mean'),
    ('config1_sd', 'model_t6_c1_sd'),
    ('config2_mean', 'model_t6_c2_mean'),
    ('config2_sd', 'model_t6_c2_sd'),
    ('config3_mean', 'model_t6_c3_mean'),
    ('config3_sd', 'model_t6_c3_sd'),
    ('benchmark_mean', 'model_t6_c4_mean'),
    ('benchmark_sd', 'model_t6_c4_sd'),]

for col in compare_col:
    # Find difference between two columns
    compare[f'change_{col[1]}'] = abs(compare[col[1]] - compare[col[0]])
    # Find percent change between two columns
    subset = compare[list(col)]
    pct_change = subset.pct_change(axis=1).iloc[:, 1]*100
    compare[f'pct_change_{col[1]}'] = pct_change

# Display each of the results
for col in compare_col:
    # Set outcome as index, and get the two results plus percent change
    subset = compare.set_index('t6_outcome')[
        list(col) + [f'change_{col[1]}', f'pct_change_{col[1]}']]
    display(subset)
# Out:
#                                                     config1_mean  \
# t6_outcome
# Doctor utilisation                                         0.268
# NCD Nurse utilisation                                      0.865
# Staff nurse utilisation                                    0.323
# Pharmacist utilisation                                     0.643
# Lab utilisation                                            0.559
# Inpatient bed utilisation                                  0.093
# Labour bed utilisation                                     0.283
# Mean length of OPD queue (number of patients)              0.000
# OPD queue waiting time (minutes)                           0.009
# Mean length of pharmacy queue (number of patients)         0.090
# Pharmacy queue waiting time (minutes)                      1.025
# Mean length of Lab queue (number of patients)              0.094
# Lab queue waiting time (minutes)                           2.084
# Fraction of childbirth cases referred                      0.156
#
#                                                     model_t6_c1_mean  \
# t6_outcome
# Doctor utilisation                                             0.269
# NCD Nurse utilisation                                          0.866
# Staff nurse utilisation                                        0.323
# Pharmacist utilisation                                         0.643
# Lab utilisation                                                0.559
# Inpatient bed utilisation                                      0.094
# Labour bed utilisation                                         0.283
# Mean length of OPD queue (number of patients)                  0.001
# OPD queue waiting time (minutes)                               0.009
# Mean length of pharmacy queue (number of patients)             0.090
# Pharmacy queue waiting time (minutes)                          1.025
# Mean length of Lab queue (number of patients)                  0.095
# Lab queue waiting time (minutes)                               2.077
# Fraction of childbirth cases referred                          0.154
#
#                                                     change_model_t6_c1_mean  \
# t6_outcome
# Doctor utilisation                                                    0.001
# NCD Nurse utilisation                                                 0.001
# Staff nurse utilisation                                               0.000
# Pharmacist utilisation                                                0.000
# Lab utilisation                                                       0.000
# Inpatient bed utilisation                                             0.001
# Labour bed utilisation                                                0.000
# Mean length of OPD queue (number of patients)                         0.001
# OPD queue waiting time (minutes)                                      0.000
# Mean length of pharmacy queue (number of patients)                    0.000
# Pharmacy queue waiting time (minutes)                                 0.000
# Mean length of Lab queue (number of patients)                         0.001
# Lab queue waiting time (minutes)                                      0.007
# Fraction of childbirth cases referred                                 0.002
#
#                                                     pct_change_model_t6_c1_mean
# t6_outcome
# Doctor utilisation                                                     0.373134
# NCD Nurse utilisation                                                  0.115607
# Staff nurse utilisation                                                0.000000
# Pharmacist utilisation                                                 0.000000
# Lab utilisation                                                        0.000000
# Inpatient bed utilisation                                              1.075269
# Labour bed utilisation                                                 0.000000
# Mean length of OPD queue (number of patients)                               inf
# OPD queue waiting time (minutes)                                       0.000000
# Mean length of pharmacy queue (number of patients)                     0.000000
# Pharmacy queue waiting time (minutes)                                  0.000000
# Mean length of Lab queue (number of patients)                          1.063830
# Lab queue waiting time (minutes)                                      -0.335893
# Fraction of childbirth cases referred                                 -1.282051
#                                                     config1_sd  \
# t6_outcome
# Doctor utilisation                                       0.003
# NCD Nurse utilisation                                    0.011
# Staff nurse utilisation                                  0.008
# Pharmacist utilisation                                   0.004
# Lab utilisation                                          0.008
# Inpatient bed utilisation                                0.004
# Labour bed utilisation                                   0.010
# Mean length of OPD queue (number of patients)            0.000
# OPD queue waiting time (minutes)                         0.004
# Mean length of pharmacy queue (number of patients)       0.002
# Pharmacy queue waiting time (minutes)                    0.021
# Mean length of Lab queue (number of patients)            0.003
# Lab queue waiting time (minutes)                         0.054
# Fraction of childbirth cases referred                    0.019
#
#                                                     model_t6_c1_sd  \
# t6_outcome
# Doctor utilisation                                           0.002
# NCD Nurse utilisation                                        0.010
# Staff nurse utilisation                                      0.008
# Pharmacist utilisation                                       0.004
# Lab utilisation                                              0.008
# Inpatient bed utilisation                                    0.004
# Labour bed utilisation                                       0.012
# Mean length of OPD queue (number of patients)                0.000
# OPD queue waiting time (minutes)                             0.003
# Mean length of pharmacy queue (number of patients)           0.002
# Pharmacy queue waiting time (minutes)                        0.022
# Mean length of Lab queue (number of patients)                0.003
# Lab queue waiting time (minutes)                             0.056
# Fraction of childbirth cases referred                        0.016
#
#                                                     change_model_t6_c1_sd  \
# t6_outcome
# Doctor utilisation                                                  0.001
# NCD Nurse utilisation                                               0.001
# Staff nurse utilisation                                             0.000
# Pharmacist utilisation                                              0.000
# Lab utilisation                                                     0.000
# Inpatient bed utilisation                                           0.000
# Labour bed utilisation                                              0.002
# Mean length of OPD queue (number of patients)                       0.000
# OPD queue waiting time (minutes)                                    0.001
# Mean length of pharmacy queue (number of patients)                  0.000
# Pharmacy queue waiting time (minutes)                               0.001
# Mean length of Lab queue (number of patients)                       0.000
# Lab queue waiting time (minutes)                                    0.002
# Fraction of childbirth cases referred                               0.003
#
#                                                     pct_change_model_t6_c1_sd
# t6_outcome
# Doctor utilisation                                                 -33.333333
# NCD Nurse utilisation                                               -9.090909
# Staff nurse utilisation                                              0.000000
# Pharmacist utilisation                                               0.000000
# Lab utilisation                                                      0.000000
# Inpatient bed utilisation                                            0.000000
# Labour bed utilisation                                              20.000000
# Mean length of OPD queue (number of patients)                             NaN
# OPD queue waiting time (minutes)                                   -25.000000
# Mean length of pharmacy queue (number of patients)                   0.000000
# Pharmacy queue waiting time (minutes)                                4.761905
# Mean length of Lab queue (number of patients)                        0.000000
# Lab queue waiting time (minutes)                                     3.703704
# Fraction of childbirth cases referred                              -15.789474
#                                                     config2_mean  \
# t6_outcome
# Doctor utilisation                                         0.372
# NCD Nurse utilisation                                      0.469
# Staff nurse utilisation                                    0.243
# Pharmacist utilisation                                     0.288
# Lab utilisation                                            0.254
# Inpatient bed utilisation                                  0.055
# Labour bed utilisation                                     0.153
# Mean length of OPD queue (number of patients)              0.007
# OPD queue waiting time (minutes)                           0.171
# Mean length of pharmacy queue (number of patients)         0.010
# Pharmacy queue waiting time (minutes)                      0.244
# Mean length of Lab queue (number of patients)              0.012
# Lab queue waiting time (minutes)                           0.606
# Fraction of childbirth cases referred                      0.088
#
#                                                     model_t6_c2_mean  \
# t6_outcome
# Doctor utilisation                                             0.372
# NCD Nurse utilisation                                          0.469
# Staff nurse utilisation                                        0.243
# Pharmacist utilisation                                         0.289
# Lab utilisation                                                0.254
# Inpatient bed utilisation                                      0.056
# Labour bed utilisation                                         0.152
# Mean length of OPD queue (number of patients)                  0.007
# OPD queue waiting time (minutes)                               0.183
# Mean length of pharmacy queue (number of patients)             0.010
# Pharmacy queue waiting time (minutes)                          0.245
# Mean length of Lab queue (number of patients)                  0.012
# Lab queue waiting time (minutes)                               0.605
# Fraction of childbirth cases referred                          0.086
#
#                                                     change_model_t6_c2_mean  \
# t6_outcome
# Doctor utilisation                                                    0.000
# NCD Nurse utilisation                                                 0.000
# Staff nurse utilisation                                               0.000
# Pharmacist utilisation                                                0.001
# Lab utilisation                                                       0.000
# Inpatient bed utilisation                                             0.001
# Labour bed utilisation                                                0.001
# Mean length of OPD queue (number of patients)                         0.000
# OPD queue waiting time (minutes)                                      0.012
# Mean length of pharmacy queue (number of patients)                    0.000
# Pharmacy queue waiting time (minutes)                                 0.001
# Mean length of Lab queue (number of patients)                         0.000
# Lab queue waiting time (minutes)                                      0.001
# Fraction of childbirth cases referred                                 0.002
#
#                                                     pct_change_model_t6_c2_mean
# t6_outcome
# Doctor utilisation                                                     0.000000
# NCD Nurse utilisation                                                  0.000000
# Staff nurse utilisation                                                0.000000
# Pharmacist utilisation                                                 0.347222
# Lab utilisation                                                        0.000000
# Inpatient bed utilisation                                              1.818182
# Labour bed utilisation                                                -0.653595
# Mean length of OPD queue (number of patients)                          0.000000
# OPD queue waiting time (minutes)                                       7.017544
# Mean length of pharmacy queue (number of patients)                     0.000000
# Pharmacy queue waiting time (minutes)                                  0.409836
# Mean length of Lab queue (number of patients)                          0.000000
# Lab queue waiting time (minutes)                                      -0.165017
# Fraction of childbirth cases referred                                 -2.272727
#                                                     config2_sd  \
# t6_outcome
# Doctor utilisation                                       0.004
# NCD Nurse utilisation                                    0.005
# Staff nurse utilisation                                  0.006
# Pharmacist utilisation                                   0.003
# Lab utilisation                                          0.004
# Inpatient bed utilisation                                0.003
# Labour bed utilisation                                   0.009
# Mean length of OPD queue (number of patients)            0.001
# OPD queue waiting time (minutes)                         0.032
# Mean length of pharmacy queue (number of patients)       0.001
# Pharmacy queue waiting time (minutes)                    0.008
# Mean length of Lab queue (number of patients)            0.001
# Lab queue waiting time (minutes)                         0.023
# Fraction of childbirth cases referred                    0.022
#
#                                                     model_t6_c2_sd  \
# t6_outcome
# Doctor utilisation                                           0.004
# NCD Nurse utilisation                                        0.006
# Staff nurse utilisation                                      0.006
# Pharmacist utilisation                                       0.003
# Lab utilisation                                              0.005
# Inpatient bed utilisation                                    0.004
# Labour bed utilisation                                       0.011
# Mean length of OPD queue (number of patients)                0.001
# OPD queue waiting time (minutes)                             0.029
# Mean length of pharmacy queue (number of patients)           0.000
# Pharmacy queue waiting time (minutes)                        0.009
# Mean length of Lab queue (number of patients)                0.001
# Lab queue waiting time (minutes)                             0.023
# Fraction of childbirth cases referred                        0.018
#
#                                                     change_model_t6_c2_sd  \
# t6_outcome
# Doctor utilisation                                                  0.000
# NCD Nurse utilisation                                               0.001
# Staff nurse utilisation                                             0.000
# Pharmacist utilisation                                              0.000
# Lab utilisation                                                     0.001
# Inpatient bed utilisation                                           0.001
# Labour bed utilisation                                              0.002
# Mean length of OPD queue (number of patients)                       0.000
# OPD queue waiting time (minutes)                                    0.003
# Mean length of pharmacy queue (number of patients)                  0.001
# Pharmacy queue waiting time (minutes)                               0.001
# Mean length of Lab queue (number of patients)                       0.000
# Lab queue waiting time (minutes)                                    0.000
# Fraction of childbirth cases referred                               0.004
#
#                                                     pct_change_model_t6_c2_sd
# t6_outcome
# Doctor utilisation                                                   0.000000
# NCD Nurse utilisation                                               20.000000
# Staff nurse utilisation                                              0.000000
# Pharmacist utilisation                                               0.000000
# Lab utilisation                                                     25.000000
# Inpatient bed utilisation                                           33.333333
# Labour bed utilisation                                              22.222222
# Mean length of OPD queue (number of patients)                        0.000000
# OPD queue waiting time (minutes)                                    -9.375000
# Mean length of pharmacy queue (number of patients)                -100.000000
# Pharmacy queue waiting time (minutes)                               12.500000
# Mean length of Lab queue (number of patients)                        0.000000
# Lab queue waiting time (minutes)                                     0.000000
# Fraction of childbirth cases referred                              -18.181818
#                                                     config3_mean  \
# t6_outcome
# Doctor utilisation                                         0.354
# NCD Nurse utilisation                                      0.468
# Staff nurse utilisation                                    0.160
# Pharmacist utilisation                                     0.289
# Lab utilisation                                            0.239
# Inpatient bed utilisation                                  0.011
# Labour bed utilisation                                       NaN
# Mean length of OPD queue (number of patients)              0.001
# OPD queue waiting time (minutes)                           0.034
# Mean length of pharmacy queue (number of patients)         0.009
# Pharmacy queue waiting time (minutes)                      0.232
# Mean length of Lab queue (number of patients)              0.011
# Lab queue waiting time (minutes)                           0.571
# Fraction of childbirth cases referred                        NaN
#
#                                                     model_t6_c3_mean  \
# t6_outcome
# Doctor utilisation                                             0.354
# NCD Nurse utilisation                                          0.468
# Staff nurse utilisation                                        0.161
# Pharmacist utilisation                                         0.288
# Lab utilisation                                                0.239
# Inpatient bed utilisation                                      0.012
# Labour bed utilisation                                           NaN
# Mean length of OPD queue (number of patients)                  0.001
# OPD queue waiting time (minutes)                               0.035
# Mean length of pharmacy queue (number of patients)             0.009
# Pharmacy queue waiting time (minutes)                          0.231
# Mean length of Lab queue (number of patients)                  0.011
# Lab queue waiting time (minutes)                               0.570
# Fraction of childbirth cases referred                            NaN
#
#                                                     change_model_t6_c3_mean  \
# t6_outcome
# Doctor utilisation                                                    0.000
# NCD Nurse utilisation                                                 0.000
# Staff nurse utilisation                                               0.001
# Pharmacist utilisation                                                0.001
# Lab utilisation                                                       0.000
# Inpatient bed utilisation                                             0.001
# Labour bed utilisation                                                  NaN
# Mean length of OPD queue (number of patients)                         0.000
# OPD queue waiting time (minutes)                                      0.001
# Mean length of pharmacy queue (number of patients)                    0.000
# Pharmacy queue waiting time (minutes)                                 0.001
# Mean length of Lab queue (number of patients)                         0.000
# Lab queue waiting time (minutes)                                      0.001
# Fraction of childbirth cases referred                                   NaN
#
#                                                     pct_change_model_t6_c3_mean
# t6_outcome
# Doctor utilisation                                                     0.000000
# NCD Nurse utilisation                                                  0.000000
# Staff nurse utilisation                                                0.625000
# Pharmacist utilisation                                                -0.346021
# Lab utilisation                                                        0.000000
# Inpatient bed utilisation                                              9.090909
# Labour bed utilisation                                                      NaN
# Mean length of OPD queue (number of patients)                          0.000000
# OPD queue waiting time (minutes)                                       2.941176
# Mean length of pharmacy queue (number of patients)                     0.000000
# Pharmacy queue waiting time (minutes)                                 -0.431034
# Mean length of Lab queue (number of patients)                          0.000000
# Lab queue waiting time (minutes)                                      -0.175131
# Fraction of childbirth cases referred                                       NaN
#                                                     config3_sd  \
# t6_outcome
# Doctor utilisation                                       0.002
# NCD Nurse utilisation                                    0.005
# Staff nurse utilisation                                  0.001
# Pharmacist utilisation                                   0.003
# Lab utilisation                                          0.004
# Inpatient bed utilisation                                0.001
# Labour bed utilisation                                     NaN
# Mean length of OPD queue (number of patients)            0.000
# OPD queue waiting time (minutes)                         0.001
# Mean length of pharmacy queue (number of patients)       0.000
# Pharmacy queue waiting time (minutes)                    0.006
# Mean length of Lab queue (number of patients)            0.000
# Lab queue waiting time (minutes)                         0.020
# Fraction of childbirth cases referred                      NaN
#
#                                                     model_t6_c3_sd  \
# t6_outcome
# Doctor utilisation                                           0.002
# NCD Nurse utilisation                                        0.005
# Staff nurse utilisation                                      0.001
# Pharmacist utilisation                                       0.002
# Lab utilisation                                              0.004
# Inpatient bed utilisation                                    0.001
# Labour bed utilisation                                         NaN
# Mean length of OPD queue (number of patients)                0.000
# OPD queue waiting time (minutes)                             0.001
# Mean length of pharmacy queue (number of patients)           0.000
# Pharmacy queue waiting time (minutes)                        0.006
# Mean length of Lab queue (number of patients)                0.000
# Lab queue waiting time (minutes)                             0.019
# Fraction of childbirth cases referred                          NaN
#
#                                                     change_model_t6_c3_sd  \
# t6_outcome
# Doctor utilisation                                                  0.000
# NCD Nurse utilisation                                               0.000
# Staff nurse utilisation                                             0.000
# Pharmacist utilisation                                              0.001
# Lab utilisation                                                     0.000
# Inpatient bed utilisation                                           0.000
# Labour bed utilisation                                                NaN
# Mean length of OPD queue (number of patients)                       0.000
# OPD queue waiting time (minutes)                                    0.000
# Mean length of pharmacy queue (number of patients)                  0.000
# Pharmacy queue waiting time (minutes)                               0.000
# Mean length of Lab queue (number of patients)                       0.000
# Lab queue waiting time (minutes)                                    0.001
# Fraction of childbirth cases referred                                 NaN
#
#                                                     pct_change_model_t6_c3_sd
# t6_outcome
# Doctor utilisation                                                   0.000000
# NCD Nurse utilisation                                                0.000000
# Staff nurse utilisation                                              0.000000
# Pharmacist utilisation                                             -33.333333
# Lab utilisation                                                      0.000000
# Inpatient bed utilisation                                            0.000000
# Labour bed utilisation                                                    NaN
# Mean length of OPD queue (number of patients)                             NaN
# OPD queue waiting time (minutes)                                     0.000000
# Mean length of pharmacy queue (number of patients)                        NaN
# Pharmacy queue waiting time (minutes)                                0.000000
# Mean length of Lab queue (number of patients)                             NaN
# Lab queue waiting time (minutes)                                    -5.000000
# Fraction of childbirth cases referred                                     NaN
#                                                     benchmark_mean  \
# t6_outcome
# Doctor utilisation                                           1.142
# NCD Nurse utilisation                                        1.232
# Staff nurse utilisation                                      0.322
# Pharmacist utilisation                                       0.855
# Lab utilisation                                              0.736
# Inpatient bed utilisation                                    0.093
# Labour bed utilisation                                       0.281
# Mean length of OPD queue (number of patients)                0.817
# OPD queue waiting time (minutes)                             6.789
# Mean length of pharmacy queue (number of patients)           0.150
# Pharmacy queue waiting time (minutes)                        1.282
# Mean length of Lab queue (number of patients)                0.188
# Lab queue waiting time (minutes)                             3.135
# Fraction of childbirth cases referred                        0.157
#
#                                                     model_t6_c4_mean  \
# t6_outcome
# Doctor utilisation                                             1.144
# NCD Nurse utilisation                                          1.231
# Staff nurse utilisation                                        0.324
# Pharmacist utilisation                                         0.855
# Lab utilisation                                                0.734
# Inpatient bed utilisation                                      0.094
# Labour bed utilisation                                         0.281
# Mean length of OPD queue (number of patients)                  0.817
# OPD queue waiting time (minutes)                               6.969
# Mean length of pharmacy queue (number of patients)             0.150
# Pharmacy queue waiting time (minutes)                          1.284
# Mean length of Lab queue (number of patients)                  0.189
# Lab queue waiting time (minutes)                               3.153
# Fraction of childbirth cases referred                          0.161
#
#                                                     change_model_t6_c4_mean  \
# t6_outcome
# Doctor utilisation                                                    0.002
# NCD Nurse utilisation                                                 0.001
# Staff nurse utilisation                                               0.002
# Pharmacist utilisation                                                0.000
# Lab utilisation                                                       0.002
# Inpatient bed utilisation                                             0.001
# Labour bed utilisation                                                0.000
# Mean length of OPD queue (number of patients)                         0.000
# OPD queue waiting time (minutes)                                      0.180
# Mean length of pharmacy queue (number of patients)                    0.000
# Pharmacy queue waiting time (minutes)                                 0.002
# Mean length of Lab queue (number of patients)                         0.001
# Lab queue waiting time (minutes)                                      0.018
# Fraction of childbirth cases referred                                 0.004
#
#                                                     pct_change_model_t6_c4_mean
# t6_outcome
# Doctor utilisation                                                     0.175131
# NCD Nurse utilisation                                                 -0.081169
# Staff nurse utilisation                                                0.621118
# Pharmacist utilisation                                                 0.000000
# Lab utilisation                                                       -0.271739
# Inpatient bed utilisation                                              1.075269
# Labour bed utilisation                                                 0.000000
# Mean length of OPD queue (number of patients)                          0.000000
# OPD queue waiting time (minutes)                                       2.651348
# Mean length of pharmacy queue (number of patients)                     0.000000
# Pharmacy queue waiting time (minutes)                                  0.156006
# Mean length of Lab queue (number of patients)                          0.531915
# Lab queue waiting time (minutes)                                       0.574163
# Fraction of childbirth cases referred                                  2.547771
#                                                     benchmark_sd  \
# t6_outcome
# Doctor utilisation                                         0.006
# NCD Nurse utilisation                                      0.019
# Staff nurse utilisation                                    0.008
# Pharmacist utilisation                                     0.005
# Lab utilisation                                            0.011
# Inpatient bed utilisation                                  0.004
# Labour bed utilisation                                     0.012
# Mean length of OPD queue (number of patients)              0.027
# OPD queue waiting time (minutes)                           0.268
# Mean length of pharmacy queue (number of patients)         0.002
# Pharmacy queue waiting time (minutes)                      0.018
# Mean length of Lab queue (number of patients)              0.001
# Lab queue waiting time (minutes)                           0.005
# Fraction of childbirth cases referred                      0.180
#
#                                                     model_t6_c4_sd  \
# t6_outcome
# Doctor utilisation                                           0.006
# NCD Nurse utilisation                                        0.019
# Staff nurse utilisation                                      0.008
# Pharmacist utilisation                                       0.004
# Lab utilisation                                              0.012
# Inpatient bed utilisation                                    0.004
# Labour bed utilisation                                       0.013
# Mean length of OPD queue (number of patients)                0.032
# OPD queue waiting time (minutes)                             0.252
# Mean length of pharmacy queue (number of patients)           0.003
# Pharmacy queue waiting time (minutes)                        0.020
# Mean length of Lab queue (number of patients)                0.006
# Lab queue waiting time (minutes)                             0.073
# Fraction of childbirth cases referred                        0.019
#
#                                                     change_model_t6_c4_sd  \
# t6_outcome
# Doctor utilisation                                                  0.000
# NCD Nurse utilisation                                               0.000
# Staff nurse utilisation                                             0.000
# Pharmacist utilisation                                              0.001
# Lab utilisation                                                     0.001
# Inpatient bed utilisation                                           0.000
# Labour bed utilisation                                              0.001
# Mean length of OPD queue (number of patients)                       0.005
# OPD queue waiting time (minutes)                                    0.016
# Mean length of pharmacy queue (number of patients)                  0.001
# Pharmacy queue waiting time (minutes)                               0.002
# Mean length of Lab queue (number of patients)                       0.005
# Lab queue waiting time (minutes)                                    0.068
# Fraction of childbirth cases referred                               0.161
#
#                                                     pct_change_model_t6_c4_sd
# t6_outcome
# Doctor utilisation                                                   0.000000
# NCD Nurse utilisation                                                0.000000
# Staff nurse utilisation                                              0.000000
# Pharmacist utilisation                                             -20.000000
# Lab utilisation                                                      9.090909
# Inpatient bed utilisation                                            0.000000
# Labour bed utilisation                                               8.333333
# Mean length of OPD queue (number of patients)                       18.518519
# OPD queue waiting time (minutes)                                    -5.970149
# Mean length of pharmacy queue (number of patients)                  50.000000
# Pharmacy queue waiting time (minutes)                               11.111111
# Mean length of Lab queue (number of patients)                      500.000000
# Lab queue waiting time (minutes)                                  1360.000000
# Fraction of childbirth cases referred                              -89.444444

# %% [markdown]
# ## Format model results like table 6, and save

# %%
compare_col = [
    ['Configuration 1', 'model_t6_c1_mean', 'model_t6_c1_sd'],
    ['Configuration 2', 'model_t6_c2_mean', 'model_t6_c2_sd'],
    ['Configuration 3', 'model_t6_c3_mean', 'model_t6_c3_sd'],
    ['Benchmark Case', 'model_t6_c4_mean', 'model_t6_c4_sd']]

# Combine each pair of columns into string as in Table 6
for col in compare_col:
    compare[col[0]] = (
        round(compare[col[1]], 3).astype(str) + ' (' +
        round(compare[col[2]], 3).astype(str) + ')')

# Set outcome name as index, and select those columns
formatted_model_res = (compare
                       .set_index('t6_outcome')
                       .rename_axis('Simulation Outcome')[
                           [item[0] for item in compare_col]])
formatted_model_res
# Out:
#                                                    Configuration 1  \
# Simulation Outcome
# Doctor utilisation                                   0.269 (0.002)
# NCD Nurse utilisation                                 0.866 (0.01)
# Staff nurse utilisation                              0.323 (0.008)
# Pharmacist utilisation                               0.643 (0.004)
# Lab utilisation                                      0.559 (0.008)
# Inpatient bed utilisation                            0.094 (0.004)
# Labour bed utilisation                               0.283 (0.012)
# Mean length of OPD queue (number of patients)          0.001 (0.0)
# OPD queue waiting time (minutes)                     0.009 (0.003)
# Mean length of pharmacy queue (number of patients)    0.09 (0.002)
# Pharmacy queue waiting time (minutes)                1.025 (0.022)
# Mean length of Lab queue (number of patients)        0.095 (0.003)
# Lab queue waiting time (minutes)                     2.077 (0.056)
# Fraction of childbirth cases referred                0.154 (0.016)
#
#                                                    Configuration 2  \
# Simulation Outcome
# Doctor utilisation                                   0.372 (0.004)
# NCD Nurse utilisation                                0.469 (0.006)
# Staff nurse utilisation                              0.243 (0.006)
# Pharmacist utilisation                               0.289 (0.003)
# Lab utilisation                                      0.254 (0.005)
# Inpatient bed utilisation                            0.056 (0.004)
# Labour bed utilisation                               0.152 (0.011)
# Mean length of OPD queue (number of patients)        0.007 (0.001)
# OPD queue waiting time (minutes)                     0.183 (0.029)
# Mean length of pharmacy queue (number of patients)      0.01 (0.0)
# Pharmacy queue waiting time (minutes)                0.245 (0.009)
# Mean length of Lab queue (number of patients)        0.012 (0.001)
# Lab queue waiting time (minutes)                     0.605 (0.023)
# Fraction of childbirth cases referred                0.086 (0.018)
#
#                                                    Configuration 3  \
# Simulation Outcome
# Doctor utilisation                                   0.354 (0.002)
# NCD Nurse utilisation                                0.468 (0.005)
# Staff nurse utilisation                              0.161 (0.001)
# Pharmacist utilisation                               0.288 (0.002)
# Lab utilisation                                      0.239 (0.004)
# Inpatient bed utilisation                            0.012 (0.001)
# Labour bed utilisation                                   nan (nan)
# Mean length of OPD queue (number of patients)          0.001 (0.0)
# OPD queue waiting time (minutes)                     0.035 (0.001)
# Mean length of pharmacy queue (number of patients)     0.009 (0.0)
# Pharmacy queue waiting time (minutes)                0.231 (0.006)
# Mean length of Lab queue (number of patients)          0.011 (0.0)
# Lab queue waiting time (minutes)                      0.57 (0.019)
# Fraction of childbirth cases referred                    nan (nan)
#
#                                                    Benchmark Case
# Simulation Outcome
# Doctor utilisation                                  1.144 (0.006)
# NCD Nurse utilisation                               1.231 (0.019)
# Staff nurse utilisation                             0.324 (0.008)
# Pharmacist utilisation                              0.855 (0.004)
# Lab utilisation                                     0.734 (0.012)
# Inpatient bed utilisation                           0.094 (0.004)
# Labour bed utilisation                              0.281 (0.013)
# Mean length of OPD queue (number of patients)       0.817 (0.032)
# OPD queue waiting time (minutes)                    6.969 (0.252)
# Mean length of pharmacy queue (number of patients)   0.15 (0.003)
# Pharmacy queue waiting time (minutes)                1.284 (0.02)
# Mean length of Lab queue (number of patients)       0.189 (0.006)
# Lab queue waiting time (minutes)                    3.153 (0.073)
# Fraction of childbirth cases referred               0.161 (0.019)

# %%
formatted_model_res.to_csv(final_results)

# %% [markdown]
# ## Run time

# %%
'''# Find run time in seconds
end = time.time()
runtime = round(end-start)

# Display converted to minutes and seconds
print(f'Notebook run time: {runtime//60}m {runtime%60}s')'''
# Out:
# "# Find run time in seconds\nend = time.time()\nruntime = round(end-start)\n\n# Display converted to minutes and seconds\nprint(f'Notebook run time: {runtime//60}m {runtime%60}s')"
